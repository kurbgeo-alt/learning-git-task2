# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       4 from sklearn.model_selection import train_test_split
# ----> 5 from tensorflow.keras.datasets import fashion_mnist
#       6 from tensorflow.keras.models import Sequential
#       7 from tensorflow.keras.layers import (
#       8     Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
#       9 )
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
(images, labels), _ = fashion_mnist.load_data()

images = images.astype("float32") / 255.0
images = np.expand_dims(images, axis=-1)

labels_cat = to_categorical(labels, 10)

X_train, X_test, y_train, y_test = train_test_split(
    images,
    labels_cat,
    test_size=0.1,
    random_state=10,
    stratify=labels
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 (images, labels), _ = fashion_mnist.load_data()
#       3 images = images.astype("float32") / 255.0
#       4 images = np.expand_dims(images, axis=-1)
#
# NameError: name 'fashion_mnist' is not defined

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(28,28,1)),
    BatchNormalization(),
    MaxPooling2D(),

    Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(),

    Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = Sequential([
#       2     Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(28,28,1)),
#       3     BatchNormalization(),
#       4     MaxPooling2D(),
#       5
#       6     Conv2D(64, (3,3), activation='relu', padding='same'),
#       7     BatchNormalization(),
#       8     MaxPooling2D(),
#       9
#      10     Conv2D(128, (3,3), activation='relu', padding='same'),
#      11     BatchNormalization(),
#      12     MaxPooling2D(),
#      13
#      14     Flatten(),
#      15     Dense(256, activation='relu'),
#      16     Dropout(0.5),
#      17     Dense(10, activation='softmax')
#      18 ])
#
# NameError: name 'Sequential' is not defined

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.1
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.compile(
#       2     optimizer=Adam(learning_rate=0.001),
#       3     loss='categorical_crossentropy',
#       4     metrics=['accuracy']
#       5 )
#       7 history = model.fit(
#       8     X_train,
#       9     y_train,
#    (...)
#      12     validation_split=0.1
#      13 )
#
# NameError: name 'model' is not defined

# %%
model.save("fashion_mnist_cnn.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.save("fashion_mnist_cnn.h5")
#
# NameError: name 'model' is not defined

# %%
from tensorflow.keras.models import load_model

model = load_model("fashion_mnist_cnn.h5")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from tensorflow.keras.models import load_model
#       3 model = load_model("fashion_mnist_cnn.h5")
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
class_names = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

# %%
def predict_and_plot(model, image):
    img = image.reshape(1,28,28,1)
    pred = model.predict(img)
    label = np.argmax(pred)

    plt.imshow(image.squeeze(), cmap="gray")
    plt.title(f"Prediction: {class_names[label]}")
    plt.axis("off")
    plt.show()

    return label

# %%
# przykład
idx = 5
predict_and_plot(model, X_test[idx])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # przykład
#       2 idx = 5
# ----> 3 predict_and_plot(model, X_test[idx])
#
# NameError: name 'model' is not defined

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    shear_range=0.1
)

datagen.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 datagen = ImageDataGenerator(
#       2     rotation_range=15,
#       3     width_shift_range=0.1,
#       4     height_shift_range=0.1,
#       5     zoom_range=0.1,
#       6     shear_range=0.1
#       7 )
#       9 datagen.fit(X_train)
#
# NameError: name 'ImageDataGenerator' is not defined

# %%
history_aug = model.fit(
    datagen.flow(X_train, y_train, batch_size=128),
    epochs=30,
    validation_data=(X_test, y_test)
)


test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test accuracy after augmentation: {test_acc:.4f}
# Out:
#   Cell In[12], line 9
#     print(f"Test accuracy after augmentation: {test_acc:.4f}
#           ^
# SyntaxError: unterminated f-string literal (detected at line 9)

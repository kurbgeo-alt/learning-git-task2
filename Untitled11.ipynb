# %%
def gauss(x, sigma=1, mu=3):
    return stats.norm.pdf(x, mu, sigma)
x = np.linspace(100, 10000)
plt.figure(figsize=(12, 8))
plt.plot(x, gauss(x, sigma=1), label='odchylenie standardowe = 1, średnia = 3')
plt.plot(x, gauss(x, sigma=2), label='odchylenie standardowe = 2, średnia = 3')
plt.plot(x, gauss(x, sigma=5), label='odchylenie standardowe = 5, średnia = 3')
plt.plot(x, gauss(x, sigma=10), label='odchylenie standardowe = 10, średnia = 3')
plt.legend(loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 def gauss(x, sigma=1, mu=3):
#       2     return stats.norm.pdf(x, mu, sigma)
# ----> 3 x = np.linspace(100, 10000)
#       4 plt.figure(figsize=(12, 8))
#       5 plt.plot(x, gauss(x, sigma=1), label='odchylenie standardowe = 1, średnia = 3')
#
# NameError: name 'np' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
def gauss(x, sigma=1, mu=3):
    return stats.norm.pdf(x, mu, sigma)
x = np.linspace( 100, 10000)
plt.figure(figsize=(12, 8))
plt.plot(x, gauss(x, sigma=1), label='odchylenie standardowe = 1, średnia = 3')
plt.plot(x, gauss(x, sigma=2), label='odchylenie standardowe = 2, średnia = 3')
plt.plot(x, gauss(x, sigma=5), label='odchylenie standardowe = 5, średnia = 3')
plt.plot(x, gauss(x, sigma=10), label='odchylenie standardowe = 10, średnia = 3')
plt.legend(loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       6 x = np.linspace( 100, 10000)
#       7 plt.figure(figsize=(12, 8))
# ----> 8 plt.plot(x, gauss(x, sigma=1), label='odchylenie standardowe = 1, średnia = 3')
#       9 plt.plot(x, gauss(x, sigma=2), label='odchylenie standardowe = 2, średnia = 3')
#      10 plt.plot(x, gauss(x, sigma=5), label='odchylenie standardowe = 5, średnia = 3')
#
# Cell In[2], line 5, in gauss(x, sigma, mu)
#       4 def gauss(x, sigma=1, mu=3):
# ----> 5     return stats.norm.pdf(x, mu, sigma)
#
# NameError: name 'stats' is not defined

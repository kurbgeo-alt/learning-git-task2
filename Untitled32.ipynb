# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt

# ===============================
# 1. Wczytywanie danych
# ===============================

movies_path = "tmdb_movies (2).csv"
genres_path = "tmdb_genres (2).csv"


df_movies = pd.read_csv(
    movies_path,
    sep=",",
    engine="python",
    quoting=csv.QUOTE_MINIMAL,
    on_bad_lines="skip"
)


df_movies = df_movies.rename(columns={df_movies.columns[-1]: "genre_id"})

# Wczytywanie gatunków
df_genres = pd.read_csv(genres_path, header=None, names=["genre_id", "genre"])

# Poprawa typów
df_genres["genre_id"] = pd.to_numeric(df_genres["genre_id"], errors="coerce").astype("Int64")
df_movies["genre_id"] = pd.to_numeric(df_movies["genre_id"], errors="coerce").astype("Int64")

# Połączenie baz
merged = df_movies.merge(df_genres, on="genre_id", how="left")


# ===============================
# 2. Top 10 filmów (vote_count > Q3)
# ===============================

merged["vote_count"] = pd.to_numeric(merged["vote_count"], errors="coerce")
merged["vote_average"] = pd.to_numeric(merged["vote_average"], errors="coerce")

q3 = merged["vote_count"].quantile(0.75)

top10 = (
    merged[merged["vote_count"] > q3]
    .sort_values("vote_average", ascending=False)
    .head(10)
)

print("\nTOP 10 FILMÓW:")
print(top10[["title", "vote_average", "vote_count", "genre"]])


# ===============================
# 3. Wykres revenue + budget (2010–2016)
# ===============================

merged["release_year"] = pd.to_numeric(merged["release_date"].str[:4], errors="coerce")
merged["revenue"] = pd.to_numeric(merged["revenue"], errors="coerce")
merged["budget"] = pd.to_numeric(merged["budget"], errors="coerce")

subset = merged[(merged["release_year"] >= 2010) & (merged["release_year"] <= 2016)]

grouped = subset.groupby("release_year")[["revenue", "budget"]].mean()

plt.figure(figsize=(10, 6))

# Kolumny – revenue
plt.bar(grouped.index, grouped["revenue"], label="Średni revenue")

# Linia – budget
plt.plot(grouped.index, grouped["budget"], linewidth=2, label="Średni budget")

plt.xlabel("Rok")
plt.ylabel("Średnie wartości (USD)")
plt.title("Średni revenue (kolumny) i budget (linia) dla lat 2010–2016")

# Legenda poza obszarem osi
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))

plt.tight_layout()
plt.show()


# ===============================
# 4. Jaki gatunek z bazy pojawia się  w niej najczęściej? Ile jest filmów z tej bazy? Najczęstszy gatunek
# ===============================

most_common_genre = merged["genre"].value_counts().head(1)
print("\nNAJCZĘSTSZY GATUNEK:")
print(most_common_genre)


# ===============================
# 5.Filmy którego gatunku trwają  średnio najdłużej? Gatunek o największym średnim runtime
# ===============================

merged["runtime"] = pd.to_numeric(merged["runtime"], errors="coerce")

avg_runtime = merged.groupby("genre")["runtime"].mean().sort_values(ascending=False)
longest_genre = avg_runtime.index[0]

print("\nGATUNEK O NAJDŁUŻSZYM ŚREDNIM CZASIE TRWANIA:")
print(f"{longest_genre} — {avg_runtime.iloc[0]:.2f} minut")


# ===============================
# 6. Histogram czasu trwania filmów
# ===============================

hist_data = merged[merged["genre"] == longest_genre]["runtime"].dropna()

plt.figure(figsize=(8, 5))
plt.hist(hist_data, bins=20, color="orange")
plt.xlabel("Runtime (min)")
plt.ylabel("Frequency")
plt.title(f"Histogram czasu trwania filmów – gatunek: {longest_genre}")
plt.tight_layout()
plt.show()
# Out:
# TOP 10 FILMÓW:
#                             title  vote_average  vote_count   genre
# 547                 Spirited Away           8.3        3840     NaN
# 546                 Spirited Away           8.3        3840  genres
# 677                          Room           8.1        2757     NaN
# 676                          Room           8.1        2757  genres
# 967  Once Upon a Time in the West           8.1        1128     NaN
# 13                   Interstellar           8.1       10867     NaN
# 12                   Interstellar           8.1       10867  genres
# 966  Once Upon a Time in the West           8.1        1128  genres
# 79                  The Lion King           8.0        5376     NaN
# 78                  The Lion King           8.0        5376  genres
# NAJCZĘSTSZY GATUNEK:
# genre
# genres    685
# Name: count, dtype: int64
#
# GATUNEK O NAJDŁUŻSZYM ŚREDNIM CZASIE TRWANIA:
# genres — 105.49 minut

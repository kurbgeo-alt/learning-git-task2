# %%
#średnia
76.84878 +81.40732 +77,57895 +68,84907+73,88595+75,26829+76,26098 + 80,57244+65,46259+67,5482+55,02451+76,2799+82,29024+69,80695+81,40112+82,19756 + 74,22683+ 80,12888+ 45,55095=1464,72/20=73.236
#Mediana
45.55 55.02,65.46,67.55,68.85,69.81 ,73.88
#wyraz 10 = 75.27
#wyraz 11 =76.26
#Mediana = 75.27+76.26/2 =151.53/2 =75.765
#minimum = 45.55
#maksimum = 82.29
#rozstęp R=82.29 - 45.55 = 36.74
y-y_ = 3.61 +8.17+4.34+0.93+(-4.39)+0.65+2.03+3.02+7.33+(-7.78) +(-5.69)+(-18.22)+3.04+9.06+(-3.43)+8.17+8.96+0.99+6.89+(-27.69)=
#(3.61)^2 +(8.17)^2 +(4.34)^2 +(0.93)^2 +(-4.39)^2 + (0.65)^2 + (2.03)^2 +(3.02)^2 + (7.33)^2 + (-7.78)^2 +(-5.69)^2 +(-18.22)^2 +(3.04)^2 +(9.06)^2 +(-3.43)^2 +(8.17)^2 +(8.96)^2 +(0.99)^2 +(6.89)^2 +(-27.69)^2/20 =1675.55
#wariancja
s^2 =suma(yi -y)^2/n-1 = 1675.55 /20-1 =1675.55/19=88,19
#odchylenie standardowe
s = 9.39
x=x1	1,3	
x2	1,95	
x3	2,466	
x4	1,6	
x5	2,952	
x6	1,801	
x7	1,34	
x8	1,34	
x9	1,63	
x10	2,326	
x11	2,436	
x12	6,563	
x13	1,283	
x14	1,43	
x15	1,988	
x16	1,61	
x17	1,921	
x18	2,4	
x19	1,495	
x20	4,705 średnia = 44,536/20=2,227
(xi-x)(yi-y) =(-0,752)(3,614)(-0,102-8,173) (0,414-4,344)(-0,452-0,928) (0,9+(-4,386)(-0,251-0,651)(-0,712-2,033)(-0,712-3,026)(-0,422-7,338)(0,274-(-7,772)(0,384-(-5,687)(4,511-(-18,210)(-0,769-3,045)(-0,622-9,056)(-0,064-(-3,428)
#korelacja między zmiennymi
#współczynnik korelacji        Korelacja ujemna
#Wzór korelacji: r = Σ(x-x̄)(y-ȳ) / √[Σ(x-x̄)² × Σ(y-ȳ)²] =                                                                                                                                                                                                                        #wspólczynnik korelacji
= 27,41*1675,53=-0,82
#średnie zmiennych = x=suma x/n=41,04/20=2,052
#Interpretacja korelacji
Przedział 95% dla środowiska
#Błąd standardowy SE=odchylenie standardowe/pierwiastek =9,09/pierwiatek z 20 =2,03
# Out:
#   Cell In[1], line 2
#     76.84878 +81.40732 +      + = 1464.72/20 = 73.236
#                                 ^
# SyntaxError: invalid syntax
